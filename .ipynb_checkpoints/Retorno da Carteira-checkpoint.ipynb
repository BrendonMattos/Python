# %%
# !pip install Alpha_vantage
# Out:
# Requirement already satisfied: Alpha_vantage in c:\users\igor brendon\anaconda3\lib\site-packages (2.3.1)
# Requirement already satisfied: requests in c:\users\igor brendon\anaconda3\lib\site-packages (from Alpha_vantage) (2.26.0)
# Requirement already satisfied: aiohttp in c:\users\igor brendon\anaconda3\lib\site-packages (from Alpha_vantage) (3.8.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\igor brendon\anaconda3\lib\site-packages (from aiohttp->Alpha_vantage) (1.7.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\igor brendon\anaconda3\lib\site-packages (from aiohttp->Alpha_vantage) (21.2.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\igor brendon\anaconda3\lib\site-packages (from aiohttp->Alpha_vantage) (1.2.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in c:\users\igor brendon\anaconda3\lib\site-packages (from aiohttp->Alpha_vantage) (2.0.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\igor brendon\anaconda3\lib\site-packages (from aiohttp->Alpha_vantage) (5.2.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\igor brendon\anaconda3\lib\site-packages (from aiohttp->Alpha_vantage) (4.0.1)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\igor brendon\anaconda3\lib\site-packages (from aiohttp->Alpha_vantage) (1.2.0)
# Requirement already satisfied: typing-extensions>=3.6.5 in c:\users\igor brendon\anaconda3\lib\site-packages (from async-timeout<5.0,>=4.0.0a3->aiohttp->Alpha_vantage) (3.10.0.2)
# Requirement already satisfied: idna>=2.0 in c:\users\igor brendon\anaconda3\lib\site-packages (from yarl<2.0,>=1.0->aiohttp->Alpha_vantage) (3.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\igor brendon\anaconda3\lib\site-packages (from requests->Alpha_vantage) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\igor brendon\anaconda3\lib\site-packages (from requests->Alpha_vantage) (2021.10.8)

# %%
import pandas as pd

carteira = pd.read_excel('Carteira.xlsx')
display(carteira)
# Out:
#   Ativos  Inicio
# 0  ITUB4   10000
# 1  ABEV3   10000
# 2  VALE3   10000
# 3  BBDC3   10000

# %%
from alpha_vantage.timeseries import TimeSeries
chave_api = "TMDQHCNKV1AMI09I"

ts = TimeSeries(key=chave_api, output_format="pandas")
data_inicial = "2021-01-05"
    
tabelas_acoes = {}
for acao in carteira["Ativos"]:
    data, meta_data = ts.get_daily_adjusted(f"{acao}.SAO", outputsize="full")
    tabelas_acoes[acao] = data
    carteira.loc[carteira["Ativos"]==acao, "Qtde"] = carteira.loc[carteira["Ativos"]==acao, "Inicio"].values / data.loc[data_inicial, "5. adjusted close"].values
display(carteira)
display(tabelas_acoes["ITUB4"])
# Out:
#   Ativos  Inicio        Qtde
# 0  ITUB4   10000  393.778303
# 1  ABEV3   10000  635.525898
# 2  VALE3   10000  126.493413
# 3  BBDC3   10000  472.737243
#              1. open   2. high    3. low  4. close  5. adjusted close  \
# date
# 2021-12-14   21.7600   22.1600   21.6800   21.7800            21.7800
# 2021-12-13   22.2000   22.4200   21.5700   21.5700            21.5700
# 2021-12-10   22.2800   22.4300   21.8700   22.1600            22.1600
# 2021-12-09   22.7800   22.7900   21.9500   22.1300            22.1300
# 2021-12-08   23.0900   23.1400   22.4500   22.7400            22.7400
# ...              ...       ...       ...       ...                ...
# 2005-01-07  327.8481  332.0021  326.1710  328.2488             4.1203
# 2005-01-06  332.8446  332.8446  326.2466  328.6653             4.1256
# 2005-01-05  332.0021  334.5047  329.4993  332.8362             4.1779
# 2005-01-04  340.3437  341.1780  336.1730  336.1730             4.2198
# 2005-01-03  333.2535  341.1864  332.8362  340.3523             4.2723
#
#              6. volume  7. dividend amount  8. split coefficient
# date
# 2021-12-14  31477500.0              0.0000                   1.0
# 2021-12-13  48532100.0              0.0000                   1.0
# 2021-12-10  20695800.0              0.0000                   1.0
# 2021-12-09  27963900.0              0.0000                   1.0
# 2021-12-08  37934300.0              0.0000                   1.0
# ...                ...                 ...                   ...
# 2005-01-07   5870326.0              0.0000                   1.0
# 2005-01-06  16940601.0              0.0000                   1.0
# 2005-01-05  39262334.0              0.0000                   1.0
# 2005-01-04  19181229.0              0.0000                   1.0
# 2005-01-03   4789268.0              0.0024                   1.0
#
# [4192 rows x 8 columns]

# %%
ts.get_symbol_search("itau")
# Out:
# (                              1. symbol                     2. name 3. type  \
#  date
#  1970-01-01 00:00:00.000000000      ITUB  Itau Unibanco Holding S.A.  Equity
#  1970-01-01 00:00:00.000000001      ITCB              Itau Corpbanca  Equity
#
#                                     4. region 5. marketOpen 6. marketClose  \
#  date
#  1970-01-01 00:00:00.000000000  United States         09:30          16:00
#  1970-01-01 00:00:00.000000001  United States         09:30          16:00
#
#                                7. timezone 8. currency 9. matchScore
#  date
#  1970-01-01 00:00:00.000000000      UTC-04         USD        0.7500
#  1970-01-01 00:00:00.000000001      UTC-04         USD        0.5000  ,
#  None)

# %%
data, meta_data = ts.get_daily_adjusted("BOVA11.SAO", outputsize="full")
ibov = data
display(ibov)
# Out:
#             1. open  2. high  3. low  4. close  5. adjusted close  6. volume  \
# date
# 2021-12-14   104.59   105.10  102.44    102.70             102.70  5746846.0
# 2021-12-13   103.90   105.41  103.46    103.50             103.50  8548419.0
# 2021-12-10   103.60   104.24  103.25    103.73             103.73  5772541.0
# 2021-12-09   103.37   103.48  101.90    102.14             102.14  7126327.0
# 2021-12-08   103.85   104.54  103.31    104.20             104.20  6093913.0
# ...             ...      ...     ...       ...                ...        ...
# 2008-12-08    37.35    38.46   36.95     38.46              38.46   103100.0
# 2008-12-05    34.51    35.35   34.11     35.35              35.35   193700.0
# 2008-12-04    35.80    36.00   35.15     35.70              35.70   128400.0
# 2008-12-03    34.73    35.40   33.90     35.31              35.31   330158.0
# 2008-12-02    35.11    35.81   34.91     35.39              35.39   759942.0
#
#             7. dividend amount  8. split coefficient
# date
# 2021-12-14                 0.0                   1.0
# 2021-12-13                 0.0                   1.0
# 2021-12-10                 0.0                   1.0
# 2021-12-09                 0.0                   1.0
# 2021-12-08                 0.0                   1.0
# ...                        ...                   ...
# 2008-12-08                 0.0                   1.0
# 2008-12-05                 0.0                   1.0
# 2008-12-04                 0.0                   1.0
# 2008-12-03                 0.0                   1.0
# 2008-12-02                 0.0                   1.0
#
# [3219 rows x 8 columns]

# %%
data_final = "2021-12-14"
ibov = ibov.loc[data_inicial : data_final, "5. adjusted close"]
ibov.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
tabela_cotacoes = pd.DataFrame()

for acao in tabelas_acoes:
    tabela_cotacoes[acao] = tabelas_acoes[acao].loc[data_inicial : data_final, "5. adjusted close"]
display(tabela_cotacoes)
# Out:
#               ITUB4    ABEV3    VALE3    BBDC3
# date
# 2021-12-14  21.7800  16.1700  77.8500  17.1500
# 2021-12-13  21.5700  16.0100  77.8600  16.9200
# 2021-12-10  22.1600  15.9500  75.6500  17.2000
# 2021-12-09  22.1300  15.8100  75.1800  17.2000
# 2021-12-08  22.7400  16.0800  75.7600  17.7300
# ...             ...      ...      ...      ...
# 2021-01-12  26.6193  16.7203  84.3174  21.7212
# 2021-01-11  26.5366  16.0236  86.6891  21.7122
# 2021-01-08  27.1487  16.4516  86.7061  22.0457
# 2021-01-07  27.1570  15.9739  86.9781  22.2169
# 2021-01-06  26.0982  15.9739  81.2742  21.6040
#
# [234 rows x 4 columns]

# %%
for acao in tabela_cotacoes.columns:
    tabela_cotacoes[acao] = tabela_cotacoes[acao] * carteira.loc[carteira["Ativos"]==acao, "Qtde"].values
display(tabela_cotacoes)
# Out:
#                    ITUB4         ABEV3         VALE3         BBDC3
# date
# 2021-12-14   8576.491435  10276.453765   9847.512191   8107.443721
# 2021-12-13   8493.797992  10174.769622   9848.777125   7998.714155
# 2021-12-10   8726.127190  10136.638068   9569.226683   8131.080583
# 2021-12-09   8714.313841  10047.664442   9509.774778   8131.080583
# 2021-12-08   8954.518606  10219.256435   9583.140958   8381.631322
# ...                  ...           ...           ...           ...
# 2021-01-12  10482.102776  10626.183667  10665.595689  10268.420207
# 2021-01-11  10449.537310  10183.412774  10965.600116  10264.165571
# 2021-01-08  10690.569010  10455.417858  10967.750504  10421.823442
# 2021-01-07  10693.837370  10151.827137  11002.156713  10502.756058
# 2021-01-06  10276.904903  10151.827137  10280.650935  10213.015402
#
# [234 rows x 4 columns]

# %%
tabela_cotacoes["Total"] = tabela_cotacoes.sum(axis=1)
display(tabela_cotacoes)
# Out:
#                    ITUB4         ABEV3         VALE3         BBDC3  \
# date
# 2021-12-14   8576.491435  10276.453765   9847.512191   8107.443721
# 2021-12-13   8493.797992  10174.769622   9848.777125   7998.714155
# 2021-12-10   8726.127190  10136.638068   9569.226683   8131.080583
# 2021-12-09   8714.313841  10047.664442   9509.774778   8131.080583
# 2021-12-08   8954.518606  10219.256435   9583.140958   8381.631322
# ...                  ...           ...           ...           ...
# 2021-01-12  10482.102776  10626.183667  10665.595689  10268.420207
# 2021-01-11  10449.537310  10183.412774  10965.600116  10264.165571
# 2021-01-08  10690.569010  10455.417858  10967.750504  10421.823442
# 2021-01-07  10693.837370  10151.827137  11002.156713  10502.756058
# 2021-01-06  10276.904903  10151.827137  10280.650935  10213.015402
#
#                    Total
# date
# 2021-12-14  73615.802224
# 2021-12-13  73032.117786
# 2021-12-10  73126.145047
# 2021-12-09  72805.667290
# 2021-12-08  74277.094641
# ...                  ...
# 2021-01-12  84084.604678
# 2021-01-11  83725.431545
# 2021-01-08  85071.121629
# 2021-01-07  84701.154555
# 2021-01-06  81844.796753
#
# [234 rows x 5 columns]

# %%
carteira_ajustado = tabela_cotacoes["Total"] / tabela_cotacoes["Total"].iloc[-1]
ibov_ajustado = ibov / ibov.iloc[-1]

import matplotlib.pyplot as plt


carteira_ajustado.plot(label="Carteira")
ibov_ajustado.plot(label="IBOV")
plt.legend()
plt.show()

# %%
retorno_carteira = carteira_ajustado[0] -1
retorno_indice = ibov_ajustado[0] -1 
print(retorno_carteira, retorno_indice)
# Out:
# -0.10054389350028903 -0.10344827586206895
